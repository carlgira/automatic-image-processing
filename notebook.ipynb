# %%
import image_processing
import matplotlib.pyplot as plt
from PIL import Image
import cv2
file_name = 'test3.jpg'
image = Image.open(file_name)
gr_image_input = cv2.imread(file_name)
pred_image = None

try:
    pred_image, _ = image_processing.predict_animal_mask(gr_image_input, 85)
except:
    print('Could not segment the image')

if pred_image is not None:
    
    final_result, _ = image_processing.test_image(file_name)
    if final_result is not None:    
        f, axarr = plt.subplots(2,3)
        axarr[0,0].imshow(image)
        axarr[0,1].imshow(final_result)
        axarr[0,2].imshow(pred_image)
    else:
        print('Could not process the image')
# Out:
# colormask (1000, 1600, 3)
# 256 384
# colormask (1000, 1600, 3)
# 256 384
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:13<00:00,  3.81it/s]
